# %%
### STUDENT PERFORMANCE ANALYSIS

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# df_orders = pd.read_csv(r"C:\Users\nhifs\OneDrive\Desktop\project DA\StudentsPerformance.csv")
# print("Data read Successfully")

# %%
d = pd.read_csv(r"C:\Users\nhifs\OneDrive\Desktop\project DA\StudentsPerformance.csv")

# %%
d
# Out:
#      Student Id  gender race/ethnicity parental level of education  \
# 0           101  female        group B           bachelor's degree
# 1           102  female        group C                some college
# 2           103  female        group B             master's degree
# 3           104    male        group A          associate's degree
# 4           105    male        group C                some college
# ..          ...     ...            ...                         ...
# 995        1096  female        group E             master's degree
# 996        1097    male        group C                 high school
# 997        1098  female        group C                 high school
# 998        1099  female        group D                some college
# 999        1100  female        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# ...

# %%
d.head()
# Out:
#    Student Id  gender race/ethnicity parental level of education  \
# 0         101  female        group B           bachelor's degree
# 1         102  female        group C                some college
# 2         103  female        group B             master's degree
# 3         104    male        group A          associate's degree
# 4         105    male        group C                some college
#
#           lunch test preparation course  math score  reading score  \
# 0      standard                    none          72             72
# 1      standard               completed          69             90
# 2      standard                    none          90             95
# 3  free/reduced                    none          47             57
# 4      standard                    none          76             78
#
#    writing score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75

# %%
d.tail()
# Out:
#      Student Id  gender race/ethnicity parental level of education  \
# 995        1096  female        group E             master's degree
# 996        1097    male        group C                 high school
# 997        1098  female        group C                 high school
# 998        1099  female        group D                some college
# 999        1100  female        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 995      standard               completed          88             99
# 996  free/reduced                    none          62             55
# 997  free/reduced               completed          59             71
# 998      standard               completed          68             78
# 999  free/reduced                    none          77             86
#
#      writing score
# 995             95
# 996             55
# 997             65
# 998             77
# 999             86

# %%
d.shape
# Out:
# (1000, 9)

# %%
d.dtypes
# Out:
# Student Id                      int64
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
d.describe()
# Out:
#         Student Id  math score  reading score  writing score
# count  1000.000000  1000.00000    1000.000000    1000.000000
# mean    600.500000    66.08900      69.169000      68.054000
# std     288.819436    15.16308      14.600192      15.195657
# min     101.000000     0.00000      17.000000      10.000000
# 25%     350.750000    57.00000      59.000000      57.750000
# 50%     600.500000    66.00000      70.000000      69.000000
# 75%     850.250000    77.00000      79.000000      79.000000
# max    1100.000000   100.00000     100.000000     100.000000

# %%
d.columns
# Out:
# Index(['Student Id', 'gender', 'race/ethnicity', 'parental level of education',
#        'lunch', 'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Student Id                   1000 non-null   int64
#  1   gender                       1000 non-null   object
#  2   race/ethnicity               1000 non-null   object
#  3   parental level of education  1000 non-null   object
#  4   lunch                        1000 non-null   object
#  5   test preparation course      1000 non-null   object
#  6   math score                   1000 non-null   int64
#  7   reading score                1000 non-null   int64
#  8   writing score                1000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 70.4+ KB

# %%
d.gender.unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
d.lunch.unique()
# Out:
# array(['standard', 'free/reduced'], dtype=object)

# %%
d["parental level of education"].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
d["test preparation course"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: test preparation course, Length: 1000, dtype: bool

# %%
d.isnull().sum()
# Out:
# Student Id                     0
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
student=d.drop(['race/ethnicity','parental level of education'],axis=1)
student.head()
# Out:
#    Student Id  gender         lunch test preparation course  math score  \
# 0         101  female      standard                    none          72
# 1         102  female      standard               completed          69
# 2         103  female      standard                    none          90
# 3         104    male  free/reduced                    none          47
# 4         105    male      standard                    none          76
#
#    reading score  writing score
# 0             72             74
# 1             90             88
# 2             95             93
# 3             57             44
# 4             78             75

# %%
sns.pairplot(d)
# Out:
# C:\Users\nhifs\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.scatterplot(x='math score',y='reading score',data=d,hue='lunch')
# Out:
# <Axes: xlabel='math score', ylabel='reading score'>

# %%
sns.scatterplot(x='math score',y='writing score',data=d,hue='lunch')
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>

# %%
sns.boxplot(x=d['math score'])
# Out:
# <Axes: xlabel='math score'>

# %%
sns.boxplot(x=d['reading score'])
# Out:
# <Axes: xlabel='reading score'>

# %%
sns.boxplot(x=d['writing score'])
# Out:
# <Axes: xlabel='writing score'>

# %%
sns.countplot(x='test preparation course',data=d)
# Out:
# <Axes: xlabel='test preparation course', ylabel='count'>

# %%
sns.countplot(x='test preparation course',data=d, hue = 'gender')
# Out:
# <Axes: xlabel='test preparation course', ylabel='count'>

# %%
sns.distplot(d['reading score'],kde=True,norm_hist=True,bins=20)
# Out:
# C:\Users\nhifs\AppData\Local\Temp\ipykernel_24424\3428192684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d['reading score'],kde=True,norm_hist=True,bins=20)
# <Axes: xlabel='reading score', ylabel='Density'>

# %%
sns.violinplot(x='math score',data=d)
# Out:
# <Axes: xlabel='math score'>

# %%
sns.violinplot(x='writing score',y='reading score',data=d)
# Out:
# <Axes: xlabel='writing score', ylabel='reading score'>

# %% [markdown]
# # THANK YOU
